# %%
# Load trained model

from ultralytics import YOLO
model = YOLO("custom_yolo11n4_model/weights/best.pt")

# %%
# Run inference on a live webcam
model.predict(
    source=0,
    show=True,
    conf=0.15,
    save= False
)
# Out:
# 1/1: 0... Success  (inf frames of shape 640x480 at 30.00 FPS)
#
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 480x640 4 Players, 192.2ms
# 0: 480x640 4 Players, 310.8ms
# 0: 480x640 4 Players, 264.3ms
# 0: 480x640 4 Players, 222.3ms
# 0: 480x640 1 Player, 263.4ms
# 0: 480x640 2 Players, 218.4ms
# 0: 480x640 1 Player, 174.2ms
# 0: 480x640 2 Players, 178.5ms
# 0: 480x640 2 Players, 184.3ms
# 0: 480x640 3 Players, 185.6ms
# 0: 480x640 2 Players, 243.7ms
# ...
